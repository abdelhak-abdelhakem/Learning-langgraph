# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    message : str

def exercice(state : AgentState) -> AgentState:
    state["message"]= state["message"] + ", you're doing an  amazing job learning LangGraph"
    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("good", exercice)

graph.set_entry_point("good")
graph.set_finish_point("good")

app = graph.compile()

# %%
result = app.invoke({"message": "Bob"})

# %%
result
# Out:
# {'message': "Bob, you're doing an  amazing job learning LangGraph"}
